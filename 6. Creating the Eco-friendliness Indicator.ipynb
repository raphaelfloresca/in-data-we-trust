# %% [markdown]
# # Creating the Eco-Friendliness Indicator

# %% [markdown]
# Let's create the environmental indicator. The purpose of this notebook is to rank each state each year according to the different criteria and calculate the average environmental ranking for each state throughout the different years. First we need to import the required libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Let's focus on the datasets containing residential water consumption and residential CO2 emission data. We need to import the CSV file and drop any column that we are not interested in, namely columns that are not in metric tons/person. We are focusing on the years between 1980 and 2015 so we drop any years not contained in that interval. The water data was recorded every five years so we decided to fill the data for the missing year using the closest recorded value (we justified that assumption in the data section of the blog). The "ffill" method allows us to propagate the last valid observation forward, and the "bfill" function the last valid observation backward. We need both to fill the water data.

# %%
data_path = "data/election+co2_and_water_use_per_capita.csv" 
data =  pd.read_csv(data_path, index_col=0)
data.drop("Residential co2 emissions, million metric tons/person",axis=1, inplace=True)
data.drop("Residential co2 emissions, million metric tons",axis=1, inplace=True)
data= data[data['Year']>1979]
data=data[data['Year']<2015]
data = data.bfill().ffill()
outcome=data['Outcome'].to_frame()
data
# Out:
#                State  Year  Population  Alignment Outcome  \
# StateYear
# Alabama1980  Alabama  1980     3893888   0.168005       R
# Alabama1981  Alabama  1981     3918531   0.168005       R
# Alabama1982  Alabama  1982     3925266   0.168005       R
# Alabama1983  Alabama  1983     3934102   0.168005       R
# Alabama1984  Alabama  1984     3951820   0.220873       R
# Alabama1985  Alabama  1985     3972523   0.220873       R
# Alabama1986  Alabama  1986     3991569   0.220873       R
# Alabama1987  Alabama  1987     4015264   0.220873       R
# Alabama1988  Alabama  1988     4023844   0.202686       R
# Alabama1989  Alabama  1989     4030222   0.202686       R
# Alabama1990  Alabama  1990     4050055   0.202686       R
# Alabama1991  Alabama  1991     4099156   0.202686       R
# Alabama1992  Alabama  1992     4154014   0.193616       R
# Alabama1993  Alabama  1993     4214202   0.193616       R
# Alabama1994  Alabama  1994     4260229   0.193616       R
# Alabama1995  Alabama  1995     4296800   0.193616       R
# Alabama1996  Alabama  1996     4331102   0.172945       R
# Alabama1997  Alabama  1997     4367935   0.172945       R
# Alabama1998  Alabama  1998     4404701   0.172945       R
# Alabama1999  Alabama  1999     4430141   0.172945       R
# Alabama2000  Alabama  2000     4452173   0.211396       R
# Alabama2001  Alabama  2001     4467634   0.211396       R
# Alabama2002  Alabama  2002     4480089   0.211396       R
# Alabama2003  Alabama  2003     4503491   0.211396       R
# Alabama2004  Alabama  2004     4530729  -0.259648       D
# Alabama2005  Alabama  2005     4569805  -0.259648       D
# Alabama2006  Alabama  2006     4628981  -0.259648       D
# Alabama2007  Alabama  2007     4672840  -0.259648       D
# Alabama2008  Alabama  2008     4718206  -0.268438       D
# Alabama2009  Alabama  2009     4757938  -0.268438       D
# ...              ...   ...         ...        ...     ...
# Wyoming1985  Wyoming  1985      499695   0.263898       R
# Wyoming1986  Wyoming  1986      495633   0.263898       R
# Wyoming1987  Wyoming  1987      476965   0.263898       R
# Wyoming1988  Wyoming  1988      465101   0.229772       R
# Wyoming1989  Wyoming  1989      458374   0.229772       R
# Wyoming1990  Wyoming  1990      453690   0.229772       R
# Wyoming1991  Wyoming  1991      459260   0.229772       R
# Wyoming2014                                              237.0
#
#              Residential co2 emissions, metric tons/person
# StateYear
# Alabama1980                                       0.924526
# Alabama1981                                       0.867672
# Alabama1982                                       0.866183
# Alabama1983                                       0.889657
# Alabama1984                                       0.835058
# Alabama1985                                       0.730015
# Alabama1986                                       0.751584
# Alabama1987                                       0.846769
# Alabama1988                                       0.844963
# Alabama1989                                       0.818813
# Alabama1990                                       0.765422
# Alabama1991                                       0.731858
# Alabama1992                                       0.770339
# Alabama1993                                       0.806796
# Alabama1994                                       0.774606
# Alabama1995                                       0.768013
# Alabama1996                                       0.854286
# Alabama1997                                       0.778400
# Alabama1998                                       0.703794
# Alabama1999                                       0.744897
# Alabama2000                                       0.831055
# Alabama2001                                       0.783412
# Alabama2002                                       0.714272
# Alabama2003                                       0.688355
# Alabama2004                                       0.662145
# Alabama2005                                       0.590835
# Alabama2006                                       0.540076
# Alabama2007                                       0.513606
# Alabama2008                                       0.529862
# Alabama2009                                       0.525438
# ...                                                    ...
# Wyoming1985                                       2.001221
# Wyoming1986                                       1.815860
# Wyoming1987                                       1.886931
# Wyoming1988                                       1.935064
# Wyoming1989                                       1.745300
# Wyoming1990                                       1.763319
# Wyoming1991                                       1.959674
# Wyoming1992                                       1.715814
# Wyoming1993                                       1.902423
# Wyoming1994                                       1.665685
# Wyoming1995                                       1.855058
# Wyoming1996                                       1.843631
# Wyoming1997                                       1.634484
# Wyoming1998                                       1.630035
# Wyoming1999                                       1.626744
# Wyoming2000                                       1.618450
# Wyoming2001                                       1.617282
# Wyoming2002                                       1.799939
# Wyoming2003                                       1.589026
# Wyoming2004                                       1.571382
# Wyoming2005                                       1.555945
# Wyoming2006                                       1.530611
# Wyoming2007                                       1.682633
# Wyoming2008                                       1.831358
# Wyoming2009                                       1.607571
# Wyoming2010                                       1.594295
# Wyoming2011                                       1.761416
# Wyoming2012                                       1.387047
# Wyoming2013                                       1.544576
# Wyoming2014                                       1.542041
#
# [1750 rows x 7 columns]

# %% [markdown]
# Now let's rank the CO2 emission data. The first function "sort_values", allows us to reorder the CO2 emission column according to the ranking position of each state, for each year. This will be used as a reference to check the results of the next line.  The inplace=False is used so that the original dataset can remain unmodified. The second function "groupby" groups the CO2 emission data into years before the rank function can be applied, as we want a ranking for each year, not a global ranking of the whole dataframe. As opposed to the "sort_values" function, the "rank" function creates a new chart to show the ranking. We convert this chart into a dataframe using the "to_frame" function. The "ascending=1" means that the state emitting the most CO2 in a specific year will be ranked first, etc.

# %%
co2_emission=data.sort_values(by=['Year','Residential co2 emissions, metric tons/person'], inplace=False)
ranked_co2=co2_emission.groupby('Year')['Residential co2 emissions, metric tons/person'].rank(ascending=1)
df1=ranked_co2.to_frame()
df1
# Out:
#                     Residential co2 emissions, metric tons/person
# StateYear
# Hawaii1980                                                    1.0
# Florida1980                                                   2.0
# Arizona1980                                                   3.0
# Tennessee1980                                                 4.0
# Idaho1980                                                     5.0
# Oregon1980                                                    6.0
# Washington1980                                                7.0
# South Carolina1980                                            8.0
# Mississippi1980                                               9.0
# Alabama1980                                                  10.0
# Texas1980                                                    11.0
# Louisiana1980                                                12.0
# Georgia1980                                                  13.0
# North Carolina1980                                           14.0
# Nevada1980                                                   15.0
# California1980                                               16.0
# Arkansas1980                                                 17.0
# Virginia1980                                                 18.0
# New Mexico1980                                               19.0
# Oklahoma1980                                                 20.0
# Wyoming1980                                                  21.0
# Kentucky1980                                                 22.0
# Colorado1980                                                 23.0
# South Dakota1980                                             24.0
# Montana1980                                                  25.0
# West Virginia1980                                            26.0
# North Dakota1980                                             27.0
# Delaware1980                                                 28.0
# Maryland1980                                                 29.0
# Missouri1980                                                 30.0
# ...                                                           ...
# West Virginia2014                                            21.0
# Delaware2014                                                 22.0
# Oklahoma2014                                                 23.0
# Maryland2014                                                 24.0
# Missouri2014                                                 25.0
# Utah2014                                                     26.0
# South Dakota2014                                             27.0
# Indiana2014                                                  28.0
# Nebraska2014                                                 29.0
# Colorado2014                                                 30.0
# North Dakota2014                                             31.0
# Kansas2014                                                   32.0
# Wyoming2014                                                  33.0
# Montana2014                                                  34.0
# Iowa2014                                                     35.0
# Ohio2014                                                     36.0
# Pennsylvania2014                                             37.0
# Wisconsin2014                                                38.0
# New York2014                                                 39.0
# Minnesota2014                                                40.0
# New Jersey2014                                               41.0
# Maine2014                                                    42.0
# Massachusetts2014                                            43.0
# New Hampshire2014                                            44.0
# Alaska2014                                                   45.0
# Connecticut2014                                              46.0
# Illinois2014                                                 47.0
# Rhode Island2014                                             48.0
# Michigan2014                                                 49.0
# Vermont2014                                                  50.0
#
# [1750 rows x 1 columns]

# %% [markdown]
# Similarly, we apply the same functions for the water consumption data. We now have a dataframe containing the ranking of the different states for the water consumption data for each year. The "rank" function assigns half values when there is a tie which explains, for example, why Arkansas and Texas in 2014 are both ranked 36.5.

# %%
water_consumption=data.sort_values(by=['Year','Total domestic water use per capita, gallons/person/day'], inplace=False)
ranked_water=water_consumption.groupby('Year')['Total domestic water use per capita, gallons/person/day'].rank(ascending=1)
df2=ranked_water.to_frame()
df2
# Out:
#                     Total domestic water use per capita, gallons/person/day
# StateYear
# Arizona1980                                                       1.0
# West Virginia1980                                                 2.0
# Wisconsin1980                                                     3.0
# Oklahoma1980                                                      4.0
# Kentucky1980                                                      5.0
# Pennsylvania1980                                                  6.0
# Mississippi1980                                                   7.0
# Alaska1980                                                        8.0
# Ohio1980                                                          9.0
# Rhode Island1980                                                 10.0
# Connecticut1980                                                  11.0
# Missouri1980                                                     12.0
# Tennessee1980                                                    13.0
# Massachusetts1980                                                14.0
# New Jersey1980                                                   15.5
# South Carolina1980                                               15.5
# North Carolina1980                                               17.0
# Virginia1980                                                     18.0
# New Hampshire1980                                                19.0
# Illinois1980                                                     21.5
# Michigan1980                                                     21.5
# North Dakota1980                                                 21.5
# Vermont1980                                                      21.5
# Delaware1980                                                     24.0
# Kansas1980                                                       25.0
# Maine1980                                                        26.0
# Alabama1980                                                      27.0
# Maryland1980                                                     28.0
# Arkansas1980                                                     29.0
# Georgia1980                                                      30.5
# ...                                                               ...
# Massachusetts2014                                                21.5
# North Carolina2014                                               21.5
# Utah2014                                                         21.5
# Connecticut2014                                                  24.0
# Iowa2014                                                         25.0
# Louisiana2014                                                    26.0
# Maine2014                                                        27.0
# Arizona2014                                                      28.0
# Florida2014                                                      29.5
# Illinois2014                                                     29.5
# New Mexico2014                                                   31.0
# Montana2014                                                      32.0
# Arkansas2014                                                     33.0
# South Carolina2014                                               34.0
# Indiana2014                                                      35.0
# Kentucky2014                                                     36.5
# Missouri2014                                                     36.5
# California2014                                                   38.0
# Michigan2014                                                     39.5
# Oklahoma2014                                                     39.5
# Wyoming2014                                                      41.0
# Tennessee2014                                                    42.0
# Wisconsin2014                                                    43.0
# Virginia2014                                                     44.0
# New Jersey2014                                                   45.0
# Delaware2014                                                     46.0
# Texas2014                                                        47.0
# Nebraska2014                                                     48.0
# Hawaii2014                                                       49.0
# Georgia2014                                                      50.0
#
# [1750 rows x 1 columns]

# %% [markdown]
# Now let's merge the water consumption data with the CO2 emission data as they have the same index (StateYear). We perform an inner merge, keeping both of the indexes as they are identical.

# %%
merge1=df1.merge(df2, left_index=True, right_index=True)
merge1
# Out:
#                     Residential co2 emissions, metric tons/person  \
# StateYear
# Hawaii1980                                                    1.0
# Florida1980                                                   2.0
# Arizona1980                                                   3.0
# Tennessee1980                                                 4.0
# Idaho1980                                                     5.0
# Oregon1980                                                    6.0
# Washington1980                                                7.0
# South Carolina1980                                            8.0
# Mississippi1980                                               9.0
# Alabama1980                                                  10.0
# Texas1980                                                    11.0
# Louisiana1980                                                12.0
# Georgia1980                                                  13.0
# North Carolina1980                                           14.0
# Nevada1980                                                   15.0
# California1980                                               16.0
# Arkansas1980                                                 17.0
# Virginia1980                                                 18.0
# New Mexico1980                                               19.0
# Oklahoma1980                                                 20.0
# Wyoming1980                                                  21.0
# Kentucky1980                                                 22.0
# Colorado1980                                                 23.0
# South Dakota1980                                             24.0
# Montana1980                                                  25.0
# West Virginia1980                                            26.0
# North Dakota1980                                             27.0
# Delaware1980                                                 28.0
# Maryland1980                                                 29.0
# Missouri1980                                                 30.0
# ...                                                           ...
# West Virginia2014                                            21.0
# Delaware2014                                                 22.0
# Oklahoma2014                                                 23.0
# Maryland2014                                                 24.0
# Missouri2014                                                 25.0
# Utah2014                                                     26.0
# South Dakota2014                                             27.0
# Indiana2014                                                  28.0
# Nebraska2014                                                 29.0
# Colorado2014                                                 30.0
# North Dakota2014                                             31.0
# Kansas2014                                                   32.0
# Wyoming2014                                                  33.0
# Montana2014                                                  34.0
# Iowa2014                                                     35.0
# Ohio2014                                                     36.0
# Pennsylvania2014                                             37.0
# Wisconsin2014                                                38.0
# New York2014                                                 39.0
# Minnesota2014                                                40.0
# New Jersey2014                                               41.0
# Maine2014                                                    42.0
# Massachusetts2014                                            43.0
# New Hampshire2014                                            44.0
# Alaska2014                                                   45.0
# Connecticut2014                                              46.0
# Illinois2014                                                 47.0
# Rhode Island2014                                             48.0
# Michigan2014                                                 49.0
# Vermont2014                                                  50.0
#
#                     Total domestic water use per capita, gallons/person/day
# StateYear
# Hawaii1980                                                       50.0
# Florida1980                                                      46.0
# Arizona1980                                                       1.0
# Tennessee1980                                                    13.0
# Idaho1980                                                        49.0
# Oregon1980                                                       40.5
# Washington1980                                                   44.0
# South Carolina1980                                               15.5
# Mississippi1980                                                   7.0
# Alabama1980                                                      27.0
# Texas1980                                                        42.0
# Louisiana1980                                                    37.5
# Georgia1980                                                      30.5
# North Carolina1980                                               17.0
# Nevada1980                                                       48.0
# California1980                                                   34.0
# Arkansas1980                                                     29.0
# Virginia1980                                                     18.0
# New Mexico1980                                                   45.0
# Oklahoma1980                                                      4.0
# Wyoming1980                                                      43.0
# Kentucky1980                                                      5.0
# Colorado1980                                                     39.0
# South Dakota1980                                                 35.0
# Montana1980                                                      37.5
# West Virginia1980                                                 2.0
# North Dakota1980                                                 21.5
# Delaware1980                                                     24.0
# Maryland1980                                                     28.0
# Missouri1980                                                     12.0
# ...                                                               ...
# West Virginia2014                                                 3.0
# Delaware2014                                                     46.0
# Oklahoma2014                                                     39.5
# Maryland2014                                                     14.0
# Missouri2014                                                     36.5
# Utah2014                                                         21.5
# South Dakota2014                                                 13.0
# Indiana2014                                                      35.0
# Nebraska2014                                                     48.0
# Colorado2014                                                     11.0
# North Dakota2014                                                  9.0
# Kansas2014                                                        5.0
# Wyoming2014                                                      41.0
# Montana2014                                                      32.0
# Iowa2014                                                         25.0
# Ohio2014                                                          4.0
# Pennsylvania2014                                                 10.0
# Wisconsin2014                                                    43.0
# New York2014                                                     17.0
# Minnesota2014                                                     7.0
# New Jersey2014                                                   45.0
# Maine2014                                                        27.0
# Massachusetts2014                                                21.5
# New Hampshire2014                                                15.5
# Alaska2014                                                        1.0
# Connecticut2014                                                  24.0
# Illinois2014                                                     29.5
# Rhode Island2014                                                 15.5
# Michigan2014                                                     39.5
# Vermont2014                                                      18.0
#
# [1750 rows x 2 columns]

# %% [markdown]
# In order to merge the ranking of the energy consumption indicators (petroleum consumption, total energy consumption and renewables consumption) with the water and CO2 ranking, we need to rename States by their full- names, to create an index identical to the "StateYear" one. To fulfill this aim, we created a dictionary associating each state abbreviation to its full name.

# %%
state_dict = {'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 'CO': 'Colorado',
'CT': 'Connecticut', 'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia', 'GU': 'Guam',
'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky',
'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland', 'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota',
'MO': 'Missouri', 'MS': 'Mississippi', 'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota', 'NE': 'Nebraska',
'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada', 'NY': 'New York', 'OH': 'Ohio',
'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'PR': 'Puerto Rico', 'RI': 'Rhode Island',
'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia',
'VI': 'Virgin Islands', 'VT': 'Vermont', 'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia', 'WY': 'Wyoming'}

# %% [markdown]
# We can now rank the total energy consumption indicator. We first open the CSV file, then reset the index to apply our dictionary that renames the States. We then apply the same methodology as for the water and CO2 data, sorting the total energy consumption values to verify our results and then grouping and ranking the total energy consumption of the states for each year. We create a new column in the total energy consumption dataframe called "Total energy consumption ranking" ,  drop the information we don't need and sort the indexes.

# %%
total_energy_consumption = pd.read_csv('./data/total_energy_consumption.csv', index_col=0)
total_energy_consumption = total_energy_consumption.reset_index()
total_energy_consumption = total_energy_consumption.replace(to_replace=state_dict)
total_energy_consumption = total_energy_consumption.sort_values(by=['Year','Per capita consumption'], inplace=False)
ranked_total_energy = total_energy_consumption.groupby('Year')['Per capita consumption'].rank(ascending=1)
ranked_total_energy = ranked_total_energy.to_frame()
total_energy_consumption['Ranking'] = ranked_total_energy
total_energy_consumption = total_energy_consumption.drop(['MSN', 'Reading'], axis=1)
total_energy_consumption = total_energy_consumption.sort_index()
total_energy_consumption.rename(columns={'Per capita consumption':'Per capital total energy consumption',
                                         'Ranking':'Total energy consumption ranking'},inplace=True)
total_energy_consumption.head()
# Out:
#     State  Year  Population  Per capital total energy consumption  \
# 0  Alaska  1970      302583                              0.601630
# 1  Alaska  1971      316000                              0.635975
# 2  Alaska  1972      326000                              0.657620
# 3  Alaska  1973      333000                              0.591502
# 4  Alaska  1974      345000                              0.584043
#
#    Total energy consumption ranking
# 0                              33.0
# 1                              34.0
# 2                              34.0
# 3                              34.0
# 4                              35.0

# %% [markdown]
# Similarly, we use exactly the same method to rename and rank the total renewable consumption dataframe and the petroleum product consumption one.

# %%
total_renewable_consumption = pd.read_csv('./data/total_renewable_consumption.csv', index_col=0)
total_renewable_consumption = total_renewable_consumption.reset_index()
total_renewable_consumption = total_renewable_consumption.replace(to_replace=state_dict)
total_renewable_consumption = total_renewable_consumption.sort_values(by=['Year','Per capita consumption'],
                                                                      inplace=False)
ranked_renewable_consumption = total_renewable_consumption.groupby('Year')['Per capita consumption'].rank(ascending=1)
ranked_renewable_consumption = ranked_renewable_consumption.to_frame()
total_renewable_consumption['Ranking'] = ranked_renewable_consumption
total_renewable_consumption = total_renewable_consumption.drop(['MSN', 'Reading', 'State', 'Year', 'Population'],
                                                               axis=1)
total_renewable_consumption = total_renewable_consumption.sort_index()
total_renewable_consumption.rename(columns={'Per capita consumption':'Per capita renewable energy consumption',
                                         'Ranking':'Renewable energy consumption ranking'},inplace=True)
total_renewable_consumption.head()
# Out:
#    Per capita renewable energy consumption  \
# 0                                 0.029199
# 1                                 0.028778
# 2                                 0.026604
# 3                                 0.023556
# 4                                 0.024142
#
#    Renewable energy consumption ranking
# 0                                  37.0
# 1                                  37.0
# 2                                  34.0
# 3                                  30.0
# 4                                  30.0

# %%
total_petroleum_consumption = pd.read_csv('./data/total_petroleum_consumption.csv',index_col=0)
total_petroleum_consumption = total_petroleum_consumption[total_petroleum_consumption['Year']<=2015]
total_petroleum_consumption = total_petroleum_consumption.reset_index()
total_petroleum_consumption = total_petroleum_consumption.replace(to_replace=state_dict)
total_petroleum_consumption = total_petroleum_consumption.sort_values(by=['Year','Per capita consumption'],
                                                                      inplace=False)
ranked_petroleum_consumption = total_petroleum_consumption.groupby('Year')['Per capita consumption'].rank(ascending=1)
ranked_petroleum_consumption = ranked_petroleum_consumption.to_frame()
total_petroleum_consumption['Ranking'] = ranked_petroleum_consumption
total_petroleum_consumption = total_petroleum_consumption.drop(['MSN', 'Reading', 'State', 'Year', 'Population'],
                                                               axis=1)
total_petroleum_consumption = total_petroleum_consumption.sort_index()
total_petroleum_consumption.rename(columns={'Per capita consumption':'Per capita petroleum product consumption',
                                         'Ranking':'Petroleum product consumption ranking'},inplace=True)
total_petroleum_consumption.head()
# Out:
#    Per capita petroleum product consumption  \
# 0                                  0.004733
# 1                                  0.005915
# 2                                  0.004561
# 3                                  0.005456
# 4                                  0.005380
#
#    Petroleum product consumption ranking
# 0                                   42.0
# 1                                   45.0
# 2                                   42.0
# 3                                   45.0
# 4                                   45.0

# %% [markdown]
# Now that we have ranked all of the energy consumption indicators, we can merge them into one dataframe. As they have the same indexes, we can use the "concat" function.

# %%
energy_data = pd.concat([total_energy_consumption, total_renewable_consumption, total_petroleum_consumption], axis=1)

# %% [markdown]
# We can now create the "StateYear" column to merge energy consumption with the CO2 and water data, dropping the columns we don't need. In order to create the "StateYear" column we need to convert the "Year" column into a string as we can only add two string types objects together.

# %%
ranked_energy_consumption=energy_data.drop(['Population','Per capital total energy consumption','Per capita renewable energy consumption','Per capita petroleum product consumption'], axis=1, inplace=False)
ranked_energy_consumption['Year'] = ranked_energy_consumption['Year'].astype(str)
ranked_energy_consumption['StateYear']=ranked_energy_consumption['State']+ranked_energy_consumption['Year']
ranked_energy_consumption.head()
# Out:
#     State  Year  Total energy consumption ranking  \
# 0  Alaska  1970                              33.0
# 1  Alaska  1971                              34.0
# 2  Alaska  1972                              34.0
# 3  Alaska  1973                              34.0
# 4  Alaska  1974                              35.0
#
#    Renewable energy consumption ranking  \
# 0                                  37.0
# 1                                  37.0
# 2                                  34.0
# 3                                  30.0
# 4                                  30.0
#
#    Petroleum product consumption ranking   StateYear
# 0                                   42.0  Alaska1970
# 1                                   45.0  Alaska1971
# 2                                   42.0  Alaska1972
# 3                                   45.0  Alaska1973
# 4                                   45.0  Alaska1974

# %% [markdown]
# The last step before creating the final dataframe is to set the "StateYear" column as an index.

# %%
merge2=ranked_energy_consumption.set_index('StateYear')
merge2.head()
# Out:
#              State  Year  Total energy consumption ranking  \
# StateYear
# Alaska1970  Alaska  1970                              33.0
# Alaska1971  Alaska  1971                              34.0
# Alaska1972  Alaska  1972                              34.0
# Alaska1973  Alaska  1973                              34.0
# Alaska1974  Alaska  1974                              35.0
#
#             Renewable energy consumption ranking  \
# StateYear
# Alaska1970                                  37.0
# Alaska1971                                  37.0
# Alaska1972                                  34.0
# Alaska1973                                  30.0
# Alaska1974                                  30.0
#
#             Petroleum product consumption ranking
# StateYear
# Alaska1970                                   42.0
# Alaska1971                                   45.0
# Alaska1972                                   42.0
# Alaska1973                                   45.0
# Alaska1974                                   45.0

# %% [markdown]
# We can finally merge the energy consumption ranking with the water and CO2 rankings. As they have the same index, namely the "StateYear" column, we can perform an inner join, keeping both of the indexes as they are. We can then merge the "Outcome" column to that dataframe to be able to see whether states were republican or democrats which will turn out to be useful for the visualisation. Finally, we can calculate the average ranking position for each state each year summing up the rankings of the individual critera and dividing by 5 (the number of criteria). After a bit of cleaning and rounding up values we now have the ranking position of each state, each year, for each criterion that we can export to a CSV file!! Hurray!

# %%
merge3=merge1.merge(merge2, left_index=True, right_index=True)
final_merge=merge3.merge(outcome,left_index=True, right_index=True)
final_merge.drop(['State','Year'], axis=1, inplace=True)
final_merge['Average ranking']=(final_merge['Total energy consumption ranking']+final_merge['Renewable energy consumption ranking']+final_merge['Petroleum product consumption ranking']+final_merge['Residential co2 emissions, metric tons/person']+final_merge['Total domestic water use per capita, gallons/person/day'])/5
final_merge['Average ranking'] = final_merge['Average ranking'].round(decimals=0)
final_merge.columns=['Residential CO2 emissions per capita','Total domestic water use per capita','Total energy consumption per capita','Renewable energy consumption per capita', 'Petroleum product consumption per capita', 'Outcome', 'Average ranking']
final_merge.to_csv('.data/environmental_indicator_ranking.csv')
final_merge
# Out:
#                     Residential CO2 emissions per capita  \
# StateYear
# Hawaii1980                                           1.0
# Florida1980                                          2.0
# Arizona1980                                          3.0
# Tennessee1980                                        4.0
# Idaho1980                                            5.0
# Oregon1980                                           6.0
# Washington1980                                       7.0
# South Carolina1980                                   8.0
# Mississippi1980                                      9.0
# Alabama1980                                         10.0
# Texas1980                                           11.0
# Louisiana1980                                       12.0
# Georgia1980                                         13.0
# North Carolina1980                                  14.0
# Nevada1980                                          15.0
# California1980                                      16.0
# Arkansas1980                                        17.0
# Virginia1980                                        18.0
# New Mexico1980                                      19.0
# Oklahoma1980                                        20.0
# Wyoming1980                                         21.0
# Kentucky1980                                        22.0
# Colorado1980                                        23.0
# South Dakota1980                                    24.0
# Montana1980                                         25.0
# West Virginia1980                                   26.0
# North Dakota1980                                    27.0
# Delaware1980                                        28.0
# Maryland1980                                        29.0
# Missouri1980                                        30.0
# ...                                                  ...
# West Virginia2014                                   21.0
# Delaware2014                                        22.0
# Oklahoma2014                                        23.0
# Maryland2014                                        24.0
# Missouri2014                                        25.0
# Utah2014                                            26.0
# South Dakota2014                                    27.0
# Indiana2014                                         28.0
# Nebraska2014                                        29.0
# Colorado2014                                        30.0
# North Dakota2014                                    31.0
# Kansas2014                                          32.0
# Wyoming2014                                         33.0
# Montana2014                                         34.0
# Iowa2014                                            35.0
# Ohio2014                                            36.0
# Pennsylvania2014                                    37.0
# Wisconsin2014                                       38.0
# New York2014                                        39.0
# Minnesota2014                                       40.0
# New Jersey2014                                      41.0
# Maine2014                                           42.0
# Massachusetts2014                                   43.0
# Virginia1980                                            32.0       R
# New Mexico1980                                          21.0       R
# Oklahoma1980                                             9.0       R
# Wyoming1980                                             24.0       R
# Kentucky1980                                            28.0       R
# Colorado1980                                            10.0       R
# South Dakota1980                                        41.0       R
# Montana1980                                             30.0       R
# West Virginia1980                                       22.0       D
# North Dakota1980                                        39.0       R
# Delaware1980                                            43.0       R
# Maryland1980                                            38.0       D
# Missouri1980                                            26.0       R
# ...                                                      ...     ...
# West Virginia2014                                       19.0       R
# Delaware2014                                            39.0       D
# Oklahoma2014                                            17.0       R
# Maryland2014                                            31.0       D
# Missouri2014                                            28.0       R
# Utah2014                                                 6.0       R
# South Dakota2014                                        38.0       R
# Indiana2014                                             24.0       R
# Nebraska2014                                            32.0       R
# Colorado2014                                            22.0       D
# North Dakota2014                                        44.0       R
# Kansas2014                                              30.0       R
# Wyoming2014                                             36.0       R
# Montana2014                                             43.0       R
# Iowa2014                                                40.0       D
# Ohio2014                                                20.0       D
# Pennsylvania2014                                        41.0       D
# Wisconsin2014                                           35.0       D
# New York2014                                            37.0       D
# Minnesota2014                                           34.0       D
# New Jersey2014                                          29.0       D
# Maine2014                                               48.0       D
# Massachusetts2014                                       45.0       D
# New Hampshire2014                                       49.0       D
# Alaska2014                                              42.0       R
# Connecticut2014                                         47.0       D
# Illinois2014                                            15.0       D
# Rhode Island2014                                        46.0       D
# Michigan2014                                            33.0       D
# Vermont2014                                             50.0       D
#
#                     Average ranking
# StateYear
# Hawaii1980                     21.0
# Florida1980                    20.0
# Arizona1980                    15.0
# Tennessee1980                  24.0
# Idaho1980                      23.0
# Oregon1980                     27.0
# Washington1980                 34.0
# South Carolina1980             27.0
# Mississippi1980                12.0
# Alabama1980                    25.0
# Texas1980                      25.0
# Louisiana1980                  23.0
# Georgia1980                    24.0
# North Carolina1980             31.0
# Nevada1980                     23.0
# California1980                 21.0
# Arkansas1980                   26.0
# Virginia1980                   30.0
# New Mexico1980                 19.0
# Oklahoma1980                    9.0
# Wyoming1980                    25.0
# Kentucky1980                   23.0
# Colorado1980                   23.0
# South Dakota1980               26.0
# Montana1980                    28.0
# West Virginia1980              15.0
# North Dakota1980               19.0
# Delaware1980                   27.0
# Maryland1980                   25.0
# Missouri1980                   21.0
# ...                             ...
# West Virginia2014              10.0
# Delaware2014                   26.0
# Oklahoma2014                   32.0
# Maryland2014                   18.0
# Missouri2014                   25.0
# Utah2014                       24.0
# South Dakota2014               34.0
# Indiana2014                    28.0
# Nebraska2014                   38.0
# Colorado2014                   20.0
# North Dakota2014               36.0
# Kansas2014                     27.0
# Wyoming2014                    30.0
# Montana2014                    38.0
# Iowa2014                       37.0
# Ohio2014                       18.0
# Pennsylvania2014               24.0
# Wisconsin2014                  29.0
# New York2014                   23.0
# Minnesota2014                  30.0
# New Jersey2014                 27.0
# Maine2014                      36.0
# Massachusetts2014              25.0
# New Hampshire2014              33.0
# Alaska2014                     32.0
# Connecticut2014                25.0
# Illinois2014                   25.0
# Rhode Island2014               24.0
# Michigan2014                   30.0
# Vermont2014                    24.0
#
# [1750 rows x 7 columns]
